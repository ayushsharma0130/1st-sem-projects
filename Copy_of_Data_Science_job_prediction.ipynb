# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushsharma0130/1st-sem-projects/blob/main/Copy_of_Data_Science_job_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data of shoolini/data_science_job.csv')

# %%
df
# Out:
#       work_year                             job_title  job_category  \
# 0          2022  Machine Learning Engineer  in office      Analysis
# 1          2020                Statistician  (Remote)         ML/AI
# 2          2022           Machine Learning Engineer           ML/AI
# 3          2022               Data Analyst  in office         ML/AI
# 4          2020                        Statistician    Data Science
# ...         ...                                   ...           ...
# 4995       2020   Machine Learning Engineer  (Remote)           NaN
# 4996       2021   Machine Learning Engineer  (Remote)           NaN
# 4997       2022           Machine Learning Engineer        Analysis
# 4998       2021                        Statistician    Data Science
# 4999       2020              Data Scientist  (Remote)   Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 0                EUR  186597         136086                 US
# ...

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.describe()
# Out:
#         work_year         salary  salary_in_usd
# count  5000.00000    5000.000000    5000.000000
# mean   2020.97680  102046.307200  114076.995800
# std       0.81951   70853.626492   49113.807687
# min    2020.00000 -198754.000000   30016.000000
# 25%    2020.00000   64295.500000   71343.750000
# 50%    2021.00000  110636.000000  114167.000000
# 75%    2022.00000  153104.750000  156665.750000
# max    2022.00000  199924.000000  199985.000000

# %%
df.isnull().sum()
# Out:
# work_year               0
# job_title               0
# job_category          500
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level      500
# employment_type         0
# work_setting            0
# company_location        0
# company_size          500
# dtype: int64

# %%
df_cleaned = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# work_year               0
# job_title               0
# job_category          500
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level      500
# employment_type         0
# work_setting            0
# company_location        0
# company_size          500
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#find outlier
sns.boxplot(df['employment_type'])
plt.show()

# %%
sns.boxplot(df["employee_residence"])
plt.show()

# %%
sns.histplot(df["salary_currency"])
plt.show()

# %%
sns.histplot(df["experience_level"])
plt.show()

# %%
sns.countplot(x = df["salary"])
plt.show()

# %%
plt.pie(x = df["experience_level"].value_counts().values,
        labels = df["experience_level"].value_counts().index, autopct='%1.1f%%')
plt.show()

# %%
sns.scatterplot(x = df["experience_level"], y = df["salary"])
plt.show()

# %%
sns.scatterplot(x = df["employee_residence"], y = df["work_setting"])
plt.show()

# %%
df['job_title'].unique()
# Out:
# array(['Machine Learning Engineer  in office', 'Statistician  (Remote)',
#        'Machine Learning Engineer  ', 'Data Analyst  in office',
#        'Statistician  ', 'Data Scientist  (Remote)', 'Data Analyst  ',
#        'Data Engineer  in office', 'Data Scientist  ',
#        'Machine Learning Engineer  (Remote)', 'Data Engineer  ',
#        'Data Engineer  (Remote)', 'Data Scientist  in office',
#        'Data Analyst  (Remote)', 'Statistician  in office'], dtype=object)

# %%
sns.scatterplot(x = df["work_year"], y = df["job_title"])
plt.show()

# %%
df.head(43)
# Out:
#     work_year                             job_title  job_category  \
# 0        2022  Machine Learning Engineer  in office      Analysis
# 1        2020                Statistician  (Remote)         ML/AI
# 2        2022           Machine Learning Engineer           ML/AI
# 3        2022               Data Analyst  in office         ML/AI
# 4        2020                        Statistician    Data Science
# 5        2020           Machine Learning Engineer     Engineering
# 6        2022               Data Analyst  in office  Data Science
# 7        2021              Data Scientist  (Remote)         ML/AI
# 8        2022                        Data Analyst             NaN
# 9        2022                Statistician  (Remote)   Engineering
# 10       2022              Data Engineer  in office  Data Science
# 11       2022                      Data Scientist    Data Science
# 12       2020   Machine Learning Engineer  (Remote)           NaN
# ...

# %%
x = df.iloc[ :5, :8]
x
# Out:
#    work_year                             job_title  job_category  \
# 0       2022  Machine Learning Engineer  in office      Analysis
# 1       2020                Statistician  (Remote)         ML/AI
# 2       2022           Machine Learning Engineer           ML/AI
# 3       2022               Data Analyst  in office         ML/AI
# 4       2020                        Statistician    Data Science
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level
# 0             EUR  186597         136086                 US               MI
# 1             JPY  110630          67982                 JP               EX
# 2             INR   61280         153309                 UK               MI
# 3             JPY  154130         135242                 DE               SE
# 4             EUR  172312          35156                 UK               MI

# %%
y = df.iloc[:, -3]
y
# Out:
# 0          Remote
# 1          Remote
# 2          Hybrid
# 3          Hybrid
# 4       In-person
#           ...
# 4995    In-person
# 4996       Remote
# 4997       Hybrid
# 4998       Remote
# 4999       Remote
# Name: work_setting, Length: 5000, dtype: object

# %%
print(len(x))
# Out:
# 5

# %%
import pandas as pd
df = pd.concat([df, new_sample_df], ignore_index=True)

print(df)
# Out:
#    feature1  feature2  label
# 0         1         3      0
# 1         2         4      1
# 2         5         6      1
# 3         5         6      1
# 4         5         6      1

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.01, random_state=50)

x_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-ca1120e6cb80> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.01, random_state=50)
#       3
#       4 x_train
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
# ...

# %%
print(x.shape)
print(y.shape)
# Out:
# (5, 8)
# (5000,)

# %%
# import pandas as pd

# Assuming x and y are NumPy arrays or Pandas DataFrames
# df = pd.DataFrame(x)
# df['target'] = y

# # Check for missing values
# print(df.isnull().sum())



# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop('target', axis=1), df['target'], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-f1f6cb036556> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(x_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
#
# ...
