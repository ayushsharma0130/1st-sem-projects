# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushsharma0130/1st-sem-projects/blob/main/house_price_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd #data manipulation
import numpy as np #mathematics
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

# %%
df = pd.read_csv('/content/drive/MyDrive/data of shoolini/data.csv')

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.sample(5)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 1772  2014-06-03 00:00:00  660000.0       3.0       2.50         2290
# 663   2014-05-14 00:00:00  339950.0       3.0       1.00         1050
# 2754  2014-06-18 00:00:00  343566.0       2.0       1.00         1100
# 2272  2014-06-11 00:00:00  850830.0       3.0       2.50         2070
# 137   2014-05-05 00:00:00  487585.0       4.0       1.75         2010
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1772      2798     3.0           0     0          4        2290
# 663       5402     1.5           0     0          4        1050
# 2754      4200     1.0           0     0          3        1100
# 2272     13241     1.5           0     0          5        1270
# 137       9211     1.0           0     0          3        1470
#
#       sqft_basement  yr_built  yr_renovated             street      city  \
# 1772              0      1953          1983   2402 Delmar Dr E   Seattle
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df["bedrooms"].unique()
# Out:
# array([3., 5., 4., 2., 6., 7., 9., 1., 8., 0.])

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
#find outlier
sns.boxplot(df['bedrooms'])
plt.show()

# %%
sns.boxplot(df["bathrooms"])
plt.show()

# %%
sns.histplot(df["floors"])
plt.show()

# %%
sns.histplot(df["waterfront"])
plt.show()

# %%
sns.histplot(df["sqft_lot"])
plt.show()

# %%
sns.histplot(df['price'])
plt.show()

# %%
sns.countplot(x = df["condition"])
plt.show()

# %%
plt.pie(x = df["condition"].value_counts().values,
        labels = df["condition"].value_counts().index, autopct='%1.1f%%')
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
sns.scatterplot(x = df["bedrooms"], y = df["bathrooms"])
plt.show()

# %%
sns.scatterplot(x = df["view"], y = df["condition"])
plt.show()

# %%
sns.scatterplot(x = df["price"], y = df["condition"])
plt.show()

# %%
sns.scatterplot(x = df["city"], y = df["view"])
plt.show()

# %%
sns.barplot(x = df["floors"], y = df["waterfront"])
plt.show()

# %%
df['condition'] = df['condition'].map({'Yes':1, 'No':0})

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.head(2)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0        NaN        1340              0      1955
# 1     2.0           0     4        NaN        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0          2005  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0       709 W Blaine St    Seattle  WA 98119     USA

# %%
x = df.iloc[ :, 2:4]

# %%
x
# Out:
#       bedrooms  bathrooms
# 0          3.0       1.50
# 1          5.0       2.50
# 2          3.0       2.00
# 3          3.0       2.25
# 4          4.0       2.50
# ...        ...        ...
# 4595       3.0       1.75
# 4596       3.0       2.50
# 4597       3.0       2.50
# 4598       4.0       2.00
# 4599       3.0       2.50
#
# [4600 rows x 2 columns]

# %%
y = df.iloc[:, -17:-16]

# %%
y
# Out:
#              price
# 0     3.130000e+05
# 1     2.384000e+06
# 2     3.420000e+05
# 3     4.200000e+05
# 4     5.500000e+05
# ...            ...
# 4595  3.081667e+05
# 4596  5.343333e+05
# 4597  4.169042e+05
# 4598  2.034000e+05
# 4599  2.206000e+05
#
# [4600 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train
# Out:
#       bedrooms  bathrooms
# 1898       4.0       2.50
# 1370       4.0       3.00
# 3038       4.0       2.50
# 2361       4.0       3.75
# 156        3.0       2.00
# ...        ...        ...
# 4426       3.0       1.00
# 466        4.0       2.00
# 3092       3.0       1.00
# 3772       2.0       1.00
# 860        2.0       1.00
#
# [3680 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
cofficent = model.coef_
intercept = model.intercept_
print(cofficent, intercept)
# Out:
# [[ 23915.88653721 227053.37122018]] [-26137.11152059]

# %%
bedrooms = 4
bathrooms = 2
performance = cofficent[0]*bedrooms + cofficent[0]*bathrooms + intercept
print(performance)
# Out:
# [ 117358.20770268 1336183.11580048]

# %%
bathrooms = 3
bedrooms = 2
performance = cofficent[0]*bedrooms + cofficent[0]*bathrooms + intercept
print(performance)
# Out:
# [  93442.32116547 1109129.74458031]

# %%
def performance(bedrooms, bathrooms):
  performance = cofficent[0]*bedrooms + cofficent[0]*bathrooms + intercept
  return performance

# %%
performance(4,6)
# Out:
# array([ 213021.75385152, 2244396.6006812 ])
