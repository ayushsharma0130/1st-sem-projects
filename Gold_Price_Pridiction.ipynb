# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushsharma0130/1st-sem-projects/blob/main/Gold_Price_Pridiction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #data manipulation
import numpy as np #mathematics
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

# %%
df = pd.read_csv('/content/drive/MyDrive/data of shoolini/GOLDdata.csv')

# %%
df
# Out:
#             Date   Price    Open    High     Low
# 0     10/27/2023  1998.5  1995.0  2019.7  1986.4
# 1     10/26/2023  1997.4  1991.2  2003.7  1981.6
# 2     10/25/2023  1994.9  1982.7  1998.6  1973.6
# 3     10/24/2023  1986.1  1984.1  1992.0  1964.6
# 4     10/23/2023  1987.8  1987.7  1994.3  1971.0
# ...          ...     ...     ...     ...     ...
# 3055    1/9/2012  1608.1  1617.7  1624.6  1605.7
# 3056    1/6/2012  1616.8  1622.4  1632.3  1609.0
# 3057    1/5/2012  1620.1  1614.4  1626.8  1597.7
# 3058    1/4/2012  1612.7  1604.9  1619.8  1593.8
# 3059    1/3/2012  1600.5  1571.0  1608.7  1566.8
#
# [3060 rows x 5 columns]

# %%
df.shape
# Out:
# (3060, 5)

# %%
df.head(2)# by default five rows extract
# Out:
#          Date   Price    Open    High     Low
# 0  10/27/2023  1998.5  1995.0  2019.7  1986.4
# 1  10/26/2023  1997.4  1991.2  2003.7  1981.6

# %%
df.tail(4)
# Out:
#           Date   Price    Open    High     Low
# 3056  1/6/2012  1616.8  1622.4  1632.3  1609.0
# 3057  1/5/2012  1620.1  1614.4  1626.8  1597.7
# 3058  1/4/2012  1612.7  1604.9  1619.8  1593.8
# 3059  1/3/2012  1600.5  1571.0  1608.7  1566.8

# %%
df.sample(5)
# Out:
#            Date   Price    Open    High     Low
# 734    1/6/2021  1908.6  1952.8  1962.5  1902.6
# 146   4/11/2023  2004.8  1991.4  2006.5  1991.4
# 1891  7/12/2016  1335.3  1356.3  1358.9  1331.0
# 1639   7/4/2017  1221.7  1220.1  1228.4  1216.5
# 2213  4/14/2015  1192.6  1198.8  1201.3  1183.5

# %%
df.sample(5)
# Out:
#            Date   Price    Open    High     Low
# 1094  8/14/2019  1527.8  1513.0  1534.9  1504.5
# 905    5/8/2020  1713.9  1727.2  1735.5  1703.1
# 18    10/3/2023  1841.5  1844.9  1849.3  1830.9
# 2481  3/31/2014  1283.8  1295.0  1299.3  1282.7
# 1673  5/17/2017  1258.7  1237.2  1261.5  1236.3

# %%
df.isnull().sum()
# Out:
# Date     0
# Price    0
# Open     0
# High     0
# Low      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low'], dtype='object')

# %%
df["High"].unique()
# Out:
# array([2019.7, 2003.7, 1998.6, ..., 1626.8, 1619.8, 1608.7])

# %%
df.head()
# Out:
#          Date   Price    Open    High     Low
# 0  10/27/2023  1998.5  1995.0  2019.7  1986.4
# 1  10/26/2023  1997.4  1991.2  2003.7  1981.6
# 2  10/25/2023  1994.9  1982.7  1998.6  1973.6
# 3  10/24/2023  1986.1  1984.1  1992.0  1964.6
# 4  10/23/2023  1987.8  1987.7  1994.3  1971.0

# %%
#find outlier
sns.boxplot(df['Price'])
plt.show()

# %%
#find outlier
sns.boxplot(df['Low'])
plt.show()

# %%
df
# Out:
#             Date   Price    Open    High     Low
# 0     10/27/2023  1998.5  1995.0  2019.7  1986.4
# 1     10/26/2023  1997.4  1991.2  2003.7  1981.6
# 2     10/25/2023  1994.9  1982.7  1998.6  1973.6
# 3     10/24/2023  1986.1  1984.1  1992.0  1964.6
# 4     10/23/2023  1987.8  1987.7  1994.3  1971.0
# ...          ...     ...     ...     ...     ...
# 3055    1/9/2012  1608.1  1617.7  1624.6  1605.7
# 3056    1/6/2012  1616.8  1622.4  1632.3  1609.0
# 3057    1/5/2012  1620.1  1614.4  1626.8  1597.7
# 3058    1/4/2012  1612.7  1604.9  1619.8  1593.8
# 3059    1/3/2012  1600.5  1571.0  1608.7  1566.8
#
# [3060 rows x 5 columns]

# %%
x = df.iloc[: , 2:5]

# %%
x
# Out:
#         Open    High     Low
# 0     1995.0  2019.7  1986.4
# 1     1991.2  2003.7  1981.6
# 2     1982.7  1998.6  1973.6
# 3     1984.1  1992.0  1964.6
# 4     1987.7  1994.3  1971.0
# ...      ...     ...     ...
# 3055  1617.7  1624.6  1605.7
# 3056  1622.4  1632.3  1609.0
# 3057  1614.4  1626.8  1597.7
# 3058  1604.9  1619.8  1593.8
# 3059  1571.0  1608.7  1566.8
#
# [3060 rows x 3 columns]

# %%
y = df.iloc[:, 1:2]

# %%
y
# Out:
#        Price
# 0     1998.5
# 1     1997.4
# 2     1994.9
# 3     1986.1
# 4     1987.8
# ...      ...
# 3055  1608.1
# 3056  1616.8
# 3057  1620.1
# 3058  1612.7
# 3059  1600.5
#
# [3060 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
x_train
# Out:
#         Open    High     Low
# 2322  1176.8  1177.5  1146.7
# 2031  1069.6  1076.6  1069.5
# 1373  1241.0  1245.8  1238.3
# 351   1819.2  1826.8  1802.5
# 2918  1573.0  1591.5  1572.1
# ...      ...     ...     ...
# 1638  1223.0  1230.0  1218.3
# 1095  1522.3  1546.1  1488.9
# 1130  1423.4  1442.9  1415.1
# 1294  1235.3  1238.4  1231.3
# 860   1808.4  1817.0  1796.5
#
# [2448 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
coefficient = model.coef_
intercept = model.intercept_
print(coefficient)
print(intercept)
# Out:
# [[-0.57122199  0.7999764   0.77200955]]
# [-0.94817119]

# %%
m = coefficient[0][0]
c = coefficient[0][1]
b = coefficient[0][2]

# %%
i = intercept[0]

# %%
from  sklearn.metrics import r2_score

# Make predictions on the test data
y_pred = model.predict(x_test)

# Calculate the R-squared score
r2 = r2_score(y_test, y_pred)

print("R-squared score:",r2)
# Out:
# R-squared score: 0.9995453328120513

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 34.86248333935149
# 4.1233784952141495

# %%
Open = 3000
High = 7000
Low = 86
Price = coefficient[0]*Open+intercept
print(Price)
# Out:
# [-1714.61414602  2398.98103728  2315.08047836]

# %%
Price = m*2000+c*7000+b*200+i
print(Price)
# Out:
# 4610.844575323882

# %%
Price = m*20000+c*40000+b*15000+i
print(Price)
# Out:
# 32153.811357348473
